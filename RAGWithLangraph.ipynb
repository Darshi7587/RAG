# %%
# %pip install langgraph langchain langchain-openai langchain-community langchain-text-splitters faiss-cpu
# Out:
# Requirement already satisfied: langgraph in c:\users\darsh\anaconda3\lib\site-packages (1.0.8)
# Requirement already satisfied: langchain in c:\users\darsh\anaconda3\lib\site-packages (1.2.9)
# Requirement already satisfied: langchain-openai in c:\users\darsh\anaconda3\lib\site-packages (1.1.7)
# Requirement already satisfied: langchain-community in c:\users\darsh\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-text-splitters in c:\users\darsh\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: faiss-cpu in c:\users\darsh\anaconda3\lib\site-packages (1.12.0)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph) (1.2.9)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph) (0.3.4)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph) (2.8.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-openai) (2.17.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (0.6.9)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: packaging in c:\users\darsh\anaconda3\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\darsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\darsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\darsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\darsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\darsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\darsh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\darsh\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\darsh\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\darsh\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\darsh\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\darsh\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\darsh\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\darsh\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\darsh\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\darsh\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\darsh\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\darsh\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.66.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\darsh\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\darsh\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\darsh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\darsh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\darsh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\darsh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\darsh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\darsh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\darsh\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\darsh\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2024.9.11)
# Requirement already satisfied: httpcore==1.* in c:\users\darsh\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\darsh\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\darsh\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (2.1)
# Requirement already satisfied: colorama in c:\users\darsh\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\darsh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from typing import TypedDict, List
from langgraph.graph import StateGraph, END
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# Initialize models
llm = ChatOpenAI(model="gpt-4.1", temperature=0)
embeddings = OpenAIEmbeddings()

# %%
llm

# %%
class AgentState(TypedDict):
    question: str
    documents: List[Document]
    answer: str
    needs_retrieval: bool

# %%
sample_texts = [
    "LangGraph is a library for building stateful, multi-actor applications with LLMs. It extends LangChain with the ability to coordinate multiple chains across multiple steps of computation in a cyclic manner.",
    "RAG (Retrieval-Augmented Generation) is a technique that combines information retrieval with text generation. It retrieves relevant documents and uses them to provide context for generating more accurate responses.",
    "Vector databases store high-dimensional vectors and enable efficient similarity search. They are commonly used in RAG systems to find relevant documents based on semantic similarity.",
    "Agentic systems are AI systems that can take actions, make decisions, and interact with their environment autonomously. They often use planning and reasoning capabilities."
]

documents=[Document(page_content=text) for text in sample_texts]

##create vector store
vectorstore = FAISS.from_documents(documents, embeddings)
retriever = vectorstore.as_retriever(k=3)

# %%
def decide_retrieval(state: AgentState) -> AgentState:
    """
    Decide if we need to retrieve documents based on the question
    """
    question = state["question"]
    
    # Simple heuristic: if question contains certain keywords, retrieve
    retrieval_keywords = ["what", "how", "explain", "describe", "tell me"]
    needs_retrieval = any(keyword in question.lower() for keyword in retrieval_keywords)
    
    return {**state, "needs_retrieval": needs_retrieval}

# %%
def retrieve_documents(state: AgentState) -> AgentState:
    """
    Retrieve relevant documents based on the question
    """
    question = state["question"]
    documents = retriever.invoke(question)
    
    return {**state, "documents": documents}

# %%
def generate_answer(state: AgentState) -> AgentState:
    """
    Generate an answer using the retrieved documents or direct response
    """
    question = state["question"]
    documents = state.get("documents", [])
    
    if documents:
        # RAG approach: use documents as context
        context = "\n\n".join([doc.page_content for doc in documents])
        prompt = f"""Based on the following context, answer the question:

Context:
{context}

Question: {question}

Answer:"""
    else:
        # Direct response without retrieval
        prompt = f"Answer the following question: {question}"
    
    response = llm.invoke(prompt)
    answer = response.content
    
    return {**state, "answer": answer}

# %%
def should_retrieve(state: AgentState) -> str:
    """
    Determine the next step based on retrieval decision
    """
    if state["needs_retrieval"]:
        return "retrieve"
    else:
        return "generate"

# %%
# Create the state graph
workflow = StateGraph(AgentState)

# Add nodes
workflow.add_node("decide", decide_retrieval)
workflow.add_node("retrieve", retrieve_documents)
workflow.add_node("generate", generate_answer)

# Set entry point
workflow.set_entry_point("decide")

# Add conditional edges
workflow.add_conditional_edges(
    "decide",
    should_retrieve,
    {
        "retrieve": "retrieve",
        "generate": "generate"
    }
)

# Add edges
workflow.add_edge("retrieve", "generate")
workflow.add_edge("generate", END)

# Compile the graph
app = workflow.compile()
app

# %%
def ask_question(question: str):
    """
    Helper function to ask a question and get an answer
    """
    initial_state = {
        "question": question,
        "documents": [],
        "answer": "",
        "needs_retrieval": False
    }
    
    result = app.invoke(initial_state)
    return result

# %%
question1 = "What is LangGraph?"
result1 = ask_question(question1)
result1
